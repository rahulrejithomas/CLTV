# %% [markdown]
# # Computing Customer lifetime Value

# %% [markdown]
# The CLV calculation is going to follow the equation below. However, there is are quite a few ways to calcuate customer lifetime value.
#
# __CLTV = ((Average Order Value x Purchase Frequency)/Churn Rate) x Profit margin__

# %% [markdown]
# # Prepare the Data with Customer Grouping

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
df = pd.read_csv("EcommerceData.csv")
df.head()
# Out:
#    Unnamed: 0 InvoiceNo StockCode                        Description  \
# 0      439570    574477     22591  CARDHOLDER GINGHAM CHRISTMAS TREE
# 1      387281    570275     23541         WALL ART CLASSIC PUDDINGS
# 2      337863    566482     22508           DOORSTOP RETROSPOT HEART
# 3       57628    541215     22662        LUNCH BAG DOLLY GIRL DESIGN
# 4      330897    565930      POST                            POSTAGE
#
#    Quantity  UnitPrice  CustomerID         Country        Date  Hour
# 0         1       3.25     15453.0  United Kingdom  2011-11-04    12
# 1        12       7.45     13098.0  United Kingdom  2011-10-10    10
# 2        12       3.75     16609.0  United Kingdom  2011-09-13     9
# 3        10       1.65     14329.0  United Kingdom  2011-01-14    13
# 4         5      18.00     12685.0          France  2011-09-08    10

# %%
#some small data wrangling task
df['Total_revenue'] = df['Quantity']*df['UnitPrice']
df['Date'] = pd.to_datetime(df['Date'])
df = df[df["Quantity"]>0]
df.head()
# Out:
#    Unnamed: 0 InvoiceNo StockCode                        Description  \
# 0      439570    574477     22591  CARDHOLDER GINGHAM CHRISTMAS TREE
# 1      387281    570275     23541         WALL ART CLASSIC PUDDINGS
# 2      337863    566482     22508           DOORSTOP RETROSPOT HEART
# 3       57628    541215     22662        LUNCH BAG DOLLY GIRL DESIGN
# 4      330897    565930      POST                            POSTAGE
#
#    Quantity  UnitPrice  CustomerID         Country       Date  Hour  \
# 0         1       3.25     15453.0  United Kingdom 2011-11-04    12
# 1        12       7.45     13098.0  United Kingdom 2011-10-10    10
# 2        12       3.75     16609.0  United Kingdom 2011-09-13     9
# 3        10       1.65     14329.0  United Kingdom 2011-01-14    13
# 4         5      18.00     12685.0          France 2011-09-08    10
#
#    Total_revenue
# 0           3.25
# 1          89.40
# 2          45.00
# 3          16.50
# 4          90.00

# %%
#Lets create grouping around the customer ID and aggregate the metrics
max_date = df['Date'].max()
df2 = df.groupby('CustomerID').agg(
    {'Date': lambda x: (max_date - x.min()).days,
     'InvoiceNo': lambda x: len(x),
     'Quantity': lambda x: x.sum(),
     'Total_revenue': lambda x: x.sum()})
df2
# Out:
#             Date  InvoiceNo  Quantity  Total_revenue
# CustomerID
# 12347.0      367         48       623        1146.59
# 12348.0      358          7       531         550.92
# 12349.0       18         16       203         406.32
# 12350.0      310          2        36          45.60
# 12352.0      296         21       163         663.33
# ...          ...        ...       ...            ...
# 18280.0      277          3         9          52.75
# 18281.0      180          2        11          33.45
# 18282.0      126          4        11          67.85
# 18283.0      337        133       240         325.54
# 18287.0      201         17       284         364.96
#
# [4094 rows x 4 columns]

# %%
max_date
# Out:
# Timestamp('2011-12-09 00:00:00')

# %%
#Lets put this all together in a function
def customer_model(data):
    max_date = data['Date'].max()
    data = data.groupby('CustomerID').agg(
        {'Date': lambda x: (max_date-x.min()).days,
         'InvoiceNo': lambda x: len(x),
         'Quantity': lambda x: x.sum(),
         'Total_revenue': lambda x: x.sum()})
    return data

data = customer_model(df)
data.head()
# Out:
#             Date  InvoiceNo  Quantity  Total_revenue
# CustomerID
# 12347.0      367         48       623        1146.59
# 12348.0      358          7       531         550.92
# 12349.0       18         16       203         406.32
# 12350.0      310          2        36          45.60
# 12352.0      296         21       163         663.33

# %%
#Change the name of the columns and insure that we dont have 0 quantity
data.columns = ['age','num_transactions','quantity','total_revenue']
data = data[data['quantity']>0]

# %%
df.head()
# Out:
#    Unnamed: 0 InvoiceNo StockCode                        Description  \
# 0      439570    574477     22591  CARDHOLDER GINGHAM CHRISTMAS TREE
# 1      387281    570275     23541         WALL ART CLASSIC PUDDINGS
# 2      337863    566482     22508           DOORSTOP RETROSPOT HEART
# 3       57628    541215     22662        LUNCH BAG DOLLY GIRL DESIGN
# 4      330897    565930      POST                            POSTAGE
#
#    Quantity  UnitPrice  CustomerID         Country       Date  Hour  \
# 0         1       3.25     15453.0  United Kingdom 2011-11-04    12
# 1        12       7.45     13098.0  United Kingdom 2011-10-10    10
# 2        12       3.75     16609.0  United Kingdom 2011-09-13     9
# 3        10       1.65     14329.0  United Kingdom 2011-01-14    13
# 4         5      18.00     12685.0          France 2011-09-08    10
#
#    Total_revenue
# 0           3.25
# 1          89.40
# 2          45.00
# 3          16.50
# 4          90.00

# %%
#Dropping column Unnamed:0
df.drop('Unnamed: 0',axis=1, inplace=True)

# %%
df.head()
# Out:
#   InvoiceNo StockCode                        Description  Quantity  UnitPrice  \
# 0    574477     22591  CARDHOLDER GINGHAM CHRISTMAS TREE         1       3.25
# 1    570275     23541         WALL ART CLASSIC PUDDINGS         12       7.45
# 2    566482     22508           DOORSTOP RETROSPOT HEART        12       3.75
# 3    541215     22662        LUNCH BAG DOLLY GIRL DESIGN        10       1.65
# 4    565930      POST                            POSTAGE         5      18.00
#
#    CustomerID         Country       Date  Hour  Total_revenue
# 0     15453.0  United Kingdom 2011-11-04    12           3.25
# 1     13098.0  United Kingdom 2011-10-10    10          89.40
# 2     16609.0  United Kingdom 2011-09-13     9          45.00
# 3     14329.0  United Kingdom 2011-01-14    13          16.50
# 4     12685.0          France 2011-09-08    10          90.00

# %%
data.head()
# Out:
#             age  num_transactions  quantity  total_revenue
# CustomerID
# 12347.0     367                48       623        1146.59
# 12348.0     358                 7       531         550.92
# 12349.0      18                16       203         406.32
# 12350.0     310                 2        36          45.60
# 12352.0     296                21       163         663.33

# %% [markdown]
# # Getting the Elements of CLTV Calculation

# %%
data['AOV'] = data['total_revenue']/data['num_transactions']
data
# Out:
#             age  num_transactions  quantity  total_revenue        AOV
# CustomerID
# 12347.0     367                48       623        1146.59  23.887292
# 12348.0     358                 7       531         550.92  78.702857
# 12349.0      18                16       203         406.32  25.395000
# 12350.0     310                 2        36          45.60  22.800000
# 12352.0     296                21       163         663.33  31.587143
# ...         ...               ...       ...            ...        ...
# 18280.0     277                 3         9          52.75  17.583333
# 18281.0     180                 2        11          33.45  16.725000
# 18282.0     126                 4        11          67.85  16.962500
# 18283.0     337               133       240         325.54   2.447669
# 18287.0     201                17       284         364.96  21.468235
#
# [4094 rows x 5 columns]

# %%
#Lets calculate the purchase frequency
purchase_freq = sum(data['num_transactions'])/len(data)
purchase_freq
# Out:
# 19.496336101612115

# %%
#Lets calculate the repeat rate
repeat_rate = data[data['num_transactions']>1].shape[0]/data.shape[0]
repeat_rate
# Out:
# 0.9291646311675623

# %%
#Lets calculate the churn rate
churn_rate = 1-repeat_rate
churn_rate
# Out:
# 0.07083536883243768

# %%
data['profit_margin'] = data['total_revenue']*.10

# %%
data.head()
# Out:
#             age  num_transactions  quantity  total_revenue        AOV  \
# CustomerID
# 12347.0     367                48       623        1146.59  23.887292
# 12348.0     358                 7       531         550.92  78.702857
# 12349.0      18                16       203         406.32  25.395000
# 12350.0     310                 2        36          45.60  22.800000
# 12352.0     296                21       163         663.33  31.587143
#
#             profit_margin
# CustomerID
# 12347.0           114.659
# 12348.0            55.092
# 12349.0            40.632
# 12350.0             4.560
# 12352.0            66.333

# %% [markdown]
# # Putting the Equation Together

# %%
data['CLTV'] = ((data['AOV']*purchase_freq)/churn_rate)*.10
data
# Out:
#             age  num_transactions  quantity  total_revenue        AOV  \
# CustomerID
# 12347.0     367                48       623        1146.59  23.887292
# 12348.0     358                 7       531         550.92  78.702857
# 12349.0      18                16       203         406.32  25.395000
# 12350.0     310                 2        36          45.60  22.800000
# 12352.0     296                21       163         663.33  31.587143
# ...         ...               ...       ...            ...        ...
# 18280.0     277                 3         9          52.75  17.583333
# 18281.0     180                 2        11          33.45  16.725000
# 18282.0     126                 4        11          67.85  16.962500
# 18283.0     337               133       240         325.54   2.447669
# 18287.0     201                17       284         364.96  21.468235
#
#             profit_margin         CLTV
# CustomerID
# 12347.0           114.659   657.460637
# ...

# %%
#import seaborn
import seaborn as sns 
print("The median CLTV is", data['CLTV'].median())
print("The avearge CLTV is", data['CLTV'].mean())
# Out:
# The median CLTV is 460.5410131773401
# The avearge CLTV is 747.7434697480135

# %%
data.sort_values(by='CLTV').reset_index()
# Out:
#       CustomerID  age  num_transactions  quantity  total_revenue          AOV  \
# 0        12977.0  156                 1         2           0.78     0.780000
# 1        14661.0   26                 1         1           0.85     0.850000
# 2        16658.0  368                 1         1           0.85     0.850000
# 3        17962.0  142                 3         3           2.99     0.996667
# 4        17859.0  304                 5         5           5.21     1.042000
# ...          ...  ...               ...       ...            ...          ...
# 4089     12931.0  239                15      5590        9344.82   622.988000
# 4090     16333.0  298                11      7840        7944.40   722.218182
# 4091     17949.0  289                10      4565        7671.45   767.145000
# 4092     16000.0    2                 5      2630        7948.30  1589.660000
# 4093     15749.0  332                 4      8898       20713.30  5178.325000
#
# ...

# %%
data.describe()
# Out:
#                age  num_transactions      quantity  total_revenue  \
# count  4094.000000       4094.000000   4094.000000    4094.000000
# mean    218.841475         19.496336    244.896190     417.610215
# std     118.193690         47.121977    978.071326    1666.980624
# min       0.000000          1.000000      1.000000       0.780000
# 25%     105.000000          4.000000     32.000000      62.640000
# 50%     245.000000          9.000000     81.000000     143.950000
# 75%     323.000000         21.000000    211.000000     358.907500
# max     373.000000       1564.000000  38077.000000   51732.280000
#
#                AOV  profit_margin           CLTV
# count  4094.000000    4094.000000    4094.000000
# mean     27.167507      41.761022     747.743470
# std      95.567378     166.698062    2630.343788
# min       0.780000       0.078000      21.468290
# 25%      10.502630       6.264000     289.068590
# 50%      16.732679      14.395000     460.541013
# ...
